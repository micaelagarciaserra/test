# %%
print("Hola")
# Out:
# Hola

# %%
print("Esto es un chino")
# Out:
# Esto es un chino

# %%
for x in range(0,10): 
    print("holis x"+ str(x))
# Out:
# holis x0
# holis x1
# holis x2
# holis x3
# holis x4
# holis x5
# holis x6
# holis x7
# holis x8
# holis x9

# %%
"hola"+str(1)
# Out:
# 'hola1'
